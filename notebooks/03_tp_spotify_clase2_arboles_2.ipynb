# %% [markdown]
# # Predicción de Abandono Temprano en Spotify — TP Minería de Datos (UTDT)
#
# **Notebook de la Clase 2** (validación formal + árboles de decisión), copia de `01_tp_spotify_clase1_knn.ipynb` con el contenido de la Clase 1 intacto (EDA, feature engineering, baseline KNN) más la sección nueva de la Clase 2 al final. Cada clase queda en su propio archivo como registro de estudio; el consolidado final para la entrega se arma más adelante, cerca de la fecha límite.

# %% [markdown]
# ## Base heredada de la Clase 1 (mínima)
#
# Cada clase vive en su propio notebook. El razonamiento completo (EDA con 2 figuras, comparación de tres conjuntos de features, barrido fino de K, chequeo temporal) queda en `01_tp_spotify_clase1_knn.ipynb` — no se repite acá, solo se usa el resultado.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score

RANDOM_STATE = 42
DATA_DIR = "../competition_data"

# Estilo único para todos los gráficos del notebook.
# Paleta categórica validada para daltonismo (orden fijo: azul, aqua, amarillo).
C_AZUL, C_AQUA, C_AMARILLO = "#2a78d6", "#1baf7a", "#eda100"
C_TEXTO, C_MUTED, C_GRILLA, C_EJES = "#0b0b0b", "#898781", "#e1e0d9", "#c3c2b7"
plt.rcParams.update({
    "axes.spines.top": False, "axes.spines.right": False,
    "axes.grid": True, "grid.color": C_GRILLA, "grid.linewidth": 0.8,
    "axes.edgecolor": C_EJES, "axes.labelcolor": C_TEXTO,
    "xtick.color": C_MUTED, "ytick.color": C_MUTED,
})

# %%
USECOLS = [
    "obs_id", "ms_played", "ts", "platform_family", "conn_country",
    "master_metadata_album_artist_name",
    "spotify_track_uri", "spotify_episode_uri", "audiobook_uri",
    "shuffle", "offline", "incognito_mode",
    "user_id",  # excluida en la Clase 1 como "identificador"; decisión revisada en la sección final de este notebook
]
DTYPES = {
    "spotify_track_uri": "string",
    "spotify_episode_uri": "string",
    "audiobook_uri": "string",
}

train_raw = pd.read_csv(f"{DATA_DIR}/train_data.txt", sep="\t", usecols=USECOLS, dtype=DTYPES)

train_raw["target"] = (train_raw["ms_played"] < 30000).astype(int)

print("Filas:", len(train_raw))
print("Proporción de abandono temprano (target=1):", train_raw["target"].mean().round(4))
train_raw[["obs_id", "ms_played", "target"]].head()
# Out:
# Filas: 911344
# Proporción de abandono temprano (target=1): 0.278
#    obs_id  ms_played  target
# 0       1       8956       1
# 1       2     202024       0
# 2       3     269480       0
# 3       4      24299       1
# 4       5      97877       0

# %%
# Mismas tres derivadas de la Clase 1 (justificación completa en esa clase, acá solo el resultado):
# content_type (qué URI está presente), hora/dia_semana (de ts, en UTC), artista_top (top 50 de train, resto -> "otros").

train_raw["content_type"] = np.select(
    [train_raw["spotify_track_uri"].notna(),
     train_raw["spotify_episode_uri"].notna(),
     train_raw["audiobook_uri"].notna()],
    ["track", "episode", "audiobook"],
    default="desconocido",
)

ts_dt = pd.to_datetime(train_raw["ts"], utc=True, format="ISO8601")
train_raw["ts_dt"] = ts_dt
train_raw["hora"] = ts_dt.dt.hour
DIAS = ["lun", "mar", "mié", "jue", "vie", "sáb", "dom"]
train_raw["dia_semana"] = ts_dt.dt.dayofweek.map(dict(enumerate(DIAS)))

col_artista = "master_metadata_album_artist_name"
TOP_ARTISTAS = train_raw[col_artista].value_counts().head(50).index
train_raw["artista_top"] = train_raw[col_artista].where(
    train_raw[col_artista].isin(TOP_ARTISTAS), "otros"
)

print("Features derivadas listas. artista_top:", train_raw["artista_top"].nunique(), "categorías (incluye 'otros').")
# Out:
# Features derivadas listas. artista_top: 51 categorías (incluye 'otros').

# %%
# La Clase 1 comparó 3 conjuntos anidados con el mismo holdout y grilla de K; ganó el conjunto C
# (todas las variables: contexto + momento + contenido), con AUC holdout aleatorio 0.6903 (K=101)
# que bajaba a 0.6477 al respetar el tiempo. Partimos directo de ese resultado ya validado.
TODAS_LAS_FEATURES = [
    "platform_family", "conn_country", "shuffle", "offline", "incognito_mode",
    "hora", "dia_semana", "content_type", "artista_top",
]
mejor_feats = TODAS_LAS_FEATURES

# %% [markdown]
# ## Clase 2 — Validación formal (train/validation/test) y Árboles de Decisión
#
# Todo lo de arriba es la base mínima heredada de la Clase 1 (`train_raw` con target y features derivadas, `TODAS_LAS_FEATURES`/`mejor_feats` = conjunto C ya validado). De acá en adelante es contenido nuevo de la Clase 2:
#
# 1. Un **esquema de validación formal train / validation / test**, que reemplaza el holdout único (y el "chequeo de honestidad" improvisado) de la Clase 1.
# 2. **Árboles de decisión** como segundo algoritmo, diseñados con lo visto en clase y comparados de forma honesta contra un campeón de KNN.

# %% [markdown]
# ### Esquema de validación: test interno + CV temporal de ventana expansiva
#
# En la Clase 1 alcanzaba con un único holdout: una sola decisión (el K). Acá vamos a tomar *muchas*: profundidad, mínimos por hoja y por split, poda por impureza (α), ventana de datos, y encima comparar dos familias de algoritmos (árbol vs. KNN). La clase lo nombró con precisión — **"overfitting the validation set"** (Andrew Ng): si mirás el mismo conjunto una y otra vez mientras probás combinaciones, tarde o temprano alguna le pega de casualidad al ruido y el número queda inflado.
#
# El esquema, adaptado a datos **no i.i.d.** (el profesor fue explícito: el TP tiene componente temporal, los gustos cambian):
#
# - **`train` (85%, cronológicamente el pasado):** acá se toman TODAS las decisiones — pero no contra un validation fijo, sino con **CV temporal de ventana expansiva**, la receta explícita de la clase para series de tiempo: entrenar con el pasado, validar con el futuro inmediato, "de a ventanas", y promediar. Promediar varias ventanas da una señal menos ruidosa que un holdout único → elegir el `argmax` es más confiable. *(Una versión anterior de este notebook usaba train/validation/test 70/15/15 con validation cronológico fijo: ese 15% quedaba ocioso durante la selección y su número único era más ruidoso — esta versión lo reemplaza por las ventanas y aprovecha esas filas como desarrollo.)*
# - **`test_interno` (15% final, hasta 2024-08-31):** no se toca hasta el final, una única vez, con los modelos ya elegidos — estimación honesta, mismo rol que el leaderboard público de Kaggle pero sin gastar submits.
# - **K-Fold aleatorio: no.** El profesor lo descarta para datasets grandes en contexto i.i.d., y además acá mezclar épocas está prohibido: **split cronológico siempre**, en el corte train/test_interno y dentro de cada ventana de la CV.

# %%
train_raw_ord = train_raw.sort_values("ts_dt").reset_index(drop=True)

n = len(train_raw_ord)
n_train = int(n * 0.85)
# train (desarrollo): todas las decisiones se toman acá, vía CV temporal interna.
# test_interno: el 15% más reciente, una sola mirada al final.

df_train = train_raw_ord.iloc[:n_train]
df_test_interno = train_raw_ord.iloc[n_train:]

def build_xy(df, features=None):
    features = TODAS_LAS_FEATURES if features is None else features
    X = df[features].fillna("missing").astype(str)
    y = df["target"]
    return X, y

X_te, y_te = build_xy(df_test_interno)

for nombre, df in [("train", df_train), ("test interno", df_test_interno)]:
    print(f"{nombre:<13} {len(df):>7} filas | {df['ts_dt'].min().date()} -> {df['ts_dt'].max().date()} "
          f"| tasa abandono {df['target'].mean():.4f}")
# Out:
# train          774642 filas | 2013-10-29 -> 2023-05-26 | tasa abandono 0.2865
# test interno   136702 filas | 2023-05-26 -> 2024-08-31 | tasa abandono 0.2298

# %% [markdown]
# **Dos observaciones honestas sobre estos números:**
#
# - `test_interno` termina el **2024-08-31**, exactamente donde termina `train_data.txt` según la consigna (test real de Kaggle: desde el 2024-09-01). No es casualidad — es la porción más reciente de nuestros datos, la más parecida en el tiempo al test real, así que es el mejor proxy interno que podemos construir.
# - La tasa de abandono en `test_interno` (≈0.230) es notablemente más baja que en `train` (≈0.287). Esto es exactamente lo que un split aleatorio (i.i.d.) escondería mezclando épocas, y que un split cronológico deja a la vista: el comportamiento de escucha cambió con el tiempo. Razón de más para validar respetando la cronología, como advirtió la clase.

# %% [markdown]
# ### Árbol de decisión: por qué el pipeline es más simple que el de KNN
#
# Un árbol parte el espacio de atributos con cortes del tipo "¿esta variable es mayor o menor a tanto?", anidados desde la raíz hacia las hojas. En clasificación, cada hoja predice la **proporción de cada clase** entre las observaciones de entrenamiento que caen ahí — directamente una probabilidad, que es lo que necesitamos para ROC-AUC.
#
# Dos diferencias con el pipeline de KNN de la Clase 1:
#
# 1. **Sin `StandardScaler`.** KNN necesitaba escalar porque la distancia euclídea se deja dominar por la variable de mayor varianza. Un árbol no calcula distancias: cada corte es un umbral sobre una única variable a la vez, y ese umbral separa las mismas observaciones esté la variable en la escala que esté. Escalar no cambia ni un solo corte que el árbol pueda elegir.
# 2. **Sigue haciendo falta `OneHotEncoder`.** La clase mostró que un árbol *podría*, en teoría, partir directo por variable categórica (una rama por categoría) — pero scikit-learn no lo tiene implementado así. Seguimos con one-hot, que la propia clase aclaró que "no es tan dramático" (ni siquiera XGBoost lo tuvo durante años y aun así competía bien).
#
# Y a diferencia de KNN (*lazy*: todo el costo está en `.predict()`), un árbol es ***eager***: todo el costo de cómputo está en `.fit()` (construir el árbol); predecir es solo recorrer ifs, casi gratis. Por eso ahora entrenamos con **todas** las filas de `train` (~638.000), sin subsamplear — el motivo por el que subsampleábamos en la Clase 1 era exclusivo de KNN.

# %%
from sklearn.tree import DecisionTreeClassifier

def build_tree_pipeline(features, **tree_kwargs):
    preprocessor = ColumnTransformer(
        transformers=[
            ("onehot", OneHotEncoder(handle_unknown="ignore"), features),
        ],
        remainder="drop",
    )
    return Pipeline(
        steps=[
            ("preprocessor", preprocessor),
            ("tree", DecisionTreeClassifier(random_state=RANDOM_STATE, **tree_kwargs)),
        ]
    )

# %% [markdown]
# ### Herramienta de validación: CV temporal de ventana expansiva
#
# Antes de elegir nada, definimos la pieza que la clase prescribe para datos con estructura temporal. `make_expanding_folds` parte `df_train` (ya ordenado por fecha) en `n_folds+1` bloques cronológicos y arma folds *expansivos*: el fold *i* entrena con todos los bloques anteriores y valida con el siguiente. Así cada validación mira **el futuro inmediato** del entrenamiento — igual que el uso real del modelo — y ningún dato futuro se filtra hacia atrás.
#
# `cv_temporal_auc` corre esos folds para un pipeline dado y devuelve el **AUC promedio** (y el de cada fold). Ese promedio es la brújula que reemplaza al holdout único: menos ruidoso, y por lo tanto elegir el `argmax` sobre él es mucho más confiable. Parámetros opcionales `subsample`/`val_subsample` existen solo para que KNN (caro al predecir) sea factible; el árbol no los necesita. `filtrar_reciente` se usa más abajo para el experimento de datos rancios.

# %%
from itertools import product
from datetime import datetime

# Log de progreso a archivo: nbconvert guarda los outputs del notebook recién al FINAL de la
# corrida, así que este archivo es la única forma de ver el avance en vivo (abrirlo en el editor,
# se actualiza línea a línea). Se reinicia en cada corrida.
LOG_PROGRESO = "../logs/03_progreso_clase2_v2.log"
with open(LOG_PROGRESO, "w", encoding="utf-8") as _f:
    _f.write(f"[{datetime.now().strftime('%H:%M:%S')}] Corrida iniciada\n")

def log_progreso(msg):
    linea = f"[{datetime.now().strftime('%H:%M:%S')}] {msg}"
    print(linea, flush=True)
    with open(LOG_PROGRESO, "a", encoding="utf-8") as f:
        f.write(linea + "\n")

def make_expanding_folds(df, n_folds=4):
    """Folds temporales de ventana expansiva. df debe venir ordenado cronológicamente.
    Divide en n_folds+1 bloques; el fold i entrena con [0..i] y valida con el bloque i+1."""
    n = len(df)
    bordes = np.linspace(0, n, n_folds + 2, dtype=int)  # n_folds+1 bloques
    folds = []
    for i in range(1, n_folds + 1):
        idx_train = np.arange(0, bordes[i])
        idx_val = np.arange(bordes[i], bordes[i + 1])
        if len(idx_val) > 0 and len(idx_train) > 0:
            folds.append((idx_train, idx_val))
    return folds

def cv_temporal_auc(df, features, pipeline_factory, n_folds=4,
                    subsample=None, val_subsample=None,
                    train_filter=None, random_state=RANDOM_STATE):
    """AUC promedio en validación con ventana expansiva temporal.
    df ordenado por tiempo; pipeline_factory(features) -> pipeline sin fit.
    subsample/val_subsample: topes de tamaño (para que KNN sea factible).
    train_filter: función opcional aplicada al train de cada fold (p. ej. quedarse con meses recientes)."""
    aucs = []
    for idx_tr, idx_val in make_expanding_folds(df, n_folds):
        df_tr = df.iloc[idx_tr]
        df_va = df.iloc[idx_val]
        if train_filter is not None:
            df_tr = train_filter(df_tr)
        if subsample is not None and len(df_tr) > subsample:
            df_tr = df_tr.sample(subsample, random_state=random_state)
        if val_subsample is not None and len(df_va) > val_subsample:
            df_va = df_va.sample(val_subsample, random_state=random_state)
        X_tr_f, y_tr_f = build_xy(df_tr, features)
        X_va_f, y_va_f = build_xy(df_va, features)
        pipe = pipeline_factory(features)
        pipe.fit(X_tr_f, y_tr_f)
        aucs.append(roc_auc_score(y_va_f, pipe.predict_proba(X_va_f)[:, 1]))
    return float(np.mean(aucs)), aucs

def filtrar_reciente(df, meses):
    """Se queda con las filas de los últimos `meses` meses, relativo al máximo ts del propio df.
    meses=None -> toda la historia."""
    if meses is None:
        return df
    corte = df["ts_dt"].max() - pd.DateOffset(months=int(meses))
    return df[df["ts_dt"] >= corte]

# %% [markdown]
# ### Eligiendo los hiperparámetros con una grilla CONJUNTA y CV temporal
#
# Dos cambios respecto del enfoque anterior (holdout único + un hiperparámetro a la vez):
#
# 1. **Grilla conjunta, no secuencial.** La clase tuneó *varios* hiperparámetros a la vez (su código de ejemplo barrió 175 combinaciones) porque los hiperparámetros **interactúan** — se ve clarísimo en que `min_samples_leaf` importa mucho más a `max_depth` alto. Adoptar de a uno se queda en óptimos locales. Barremos entonces el producto de:
#    - `max_depth`: niveles de cortes (poca → underfitting; mucha → overfitting).
#    - `min_samples_leaf`: mínimo de observaciones por hoja (freno directo al overfitting).
#    - `min_samples_split`: mínimo para siquiera intentar partir un nodo (la clase también lo tuneó; antes lo dejábamos en default).
#    - `min_impurity_decrease` (el **α** de la clase): solo acepta un split si baja la impureza al menos α — "el precio que pagás por un split". Es otro control de flexibilidad, al mismo nivel que la profundidad, así que va *dentro* de la grilla.
#
#    `criterion` (gini vs. entropía) queda **fuera del barrido, fijo en gini, por cómputo**: la clase presentó los dos como casi equivalentes, así que es el eje que menos información pierde al recortarse. Si sobra tiempo antes de la entrega, se repone en una corrida final.
#
# 2. **Selección por CV temporal, no por un holdout único.** Cada combinación se evalúa con el AUC promedio de las ventanas expansivas. El profesor fue textual: *"nunca hay regla de dedo, la regla es probar"* — probamos, pero sobre una señal menos ruidosa. `test_interno` no se toca todavía.

# %%
# Grilla CONJUNTA (la clase tuneó varios hiperparámetros a la vez, no de a uno).
# criterion queda fijo en gini (casi equivalente a entropía según la clase) para recortar cómputo.
param_grid = {
    "max_depth":             [4, 6, 8, 10, 14, 20],
    "min_samples_leaf":      [1, 20, 100],
    "min_samples_split":     [2, 50],
    "min_impurity_decrease": [0.0, 1e-4],
}
N_FOLDS = 4  # ventanas expansivas temporales dentro de df_train

combos = [dict(zip(param_grid, vals)) for vals in product(*param_grid.values())]
log_progreso(f"FASE 1/5 — Grilla del árbol: {len(combos)} combinaciones x {N_FOLDS} folds temporales")

resultados = []
for i, params in enumerate(combos, 1):
    factory = lambda feats, p=params: build_tree_pipeline(feats, **p)
    auc_mean, auc_folds = cv_temporal_auc(df_train, mejor_feats, factory, n_folds=N_FOLDS)
    resultados.append({**params, "auc_cv": auc_mean, "auc_folds": auc_folds})
    log_progreso(f"  árbol {i}/{len(combos)} | {params} | AUC CV {auc_mean:.4f}")

res_df = pd.DataFrame(resultados).sort_values("auc_cv", ascending=False).reset_index(drop=True)
mejor_params = {k: res_df.loc[0, k] for k in param_grid}
mejor_params["max_depth"] = int(mejor_params["max_depth"])
mejor_params["min_samples_leaf"] = int(mejor_params["min_samples_leaf"])
mejor_params["min_samples_split"] = int(mejor_params["min_samples_split"])
mejor_params["min_impurity_decrease"] = float(mejor_params["min_impurity_decrease"])
mejor_auc_arbol = float(res_df.loc[0, "auc_cv"])

# alias por compatibilidad con menciones sueltas
mejor_depth = mejor_params["max_depth"]
mejor_leaf = mejor_params["min_samples_leaf"]

log_progreso(f"FASE 1 lista. Mejor: {mejor_params} | AUC CV {mejor_auc_arbol:.4f}")

print("\nMejores hiperparámetros (CV temporal):")
for k, v in mejor_params.items():
    print(f"  {k}: {v}")
print(f"AUC CV temporal (promedio de {N_FOLDS} ventanas): {mejor_auc_arbol:.4f}")
res_df.drop(columns="auc_folds").head(10)
# Out:
# [22:45:36] FASE 1/5 — Grilla del árbol: 72 combinaciones x 4 folds temporales
# [22:45:44]   árbol 1/72 | {'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6560
# [22:45:51]   árbol 2/72 | {'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6557
# [22:46:16]   árbol 3/72 | {'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6560
# [22:46:42]   árbol 4/72 | {'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6557
# [22:46:49]   árbol 5/72 | {'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6560
# [22:46:56]   árbol 6/72 | {'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6557
# [22:47:07]   árbol 7/72 | {'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6560
# [22:47:16]   árbol 8/72 | {'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6557
# [22:47:37]   árbol 9/72 | {'max_depth': 4, 'min_samples_leaf': 100, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6560
# [22:47:46]   árbol 10/72 | {'max_depth': 4, 'min_samples_leaf': 100, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6557
# [22:47:54]   árbol 11/72 | {'max_depth': 4, 'min_samples_leaf': 100, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6560
# [22:48:02]   árbol 12/72 | {'max_depth': 4, 'min_samples_leaf': 100, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6557
# [22:48:11]   árbol 13/72 | {'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6614
# [22:48:20]   árbol 14/72 | {'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6621
# [22:48:31]   árbol 15/72 | {'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6614
# [22:48:39]   árbol 16/72 | {'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6621
# [22:48:48]   árbol 17/72 | {'max_depth': 6, 'min_samples_leaf': 20, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6613
# [22:48:56]   árbol 18/72 | {'max_depth': 6, 'min_samples_leaf': 20, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6621
# [22:49:05]   árbol 19/72 | {'max_depth': 6, 'min_samples_leaf': 20, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6613
# [22:49:13]   árbol 20/72 | {'max_depth': 6, 'min_samples_leaf': 20, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6621
# [22:49:24]   árbol 21/72 | {'max_depth': 6, 'min_samples_leaf': 100, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6617
# [22:49:34]   árbol 22/72 | {'max_depth': 6, 'min_samples_leaf': 100, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6621
# [22:49:45]   árbol 23/72 | {'max_depth': 6, 'min_samples_leaf': 100, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6617
# [22:49:55]   árbol 24/72 | {'max_depth': 6, 'min_samples_leaf': 100, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6621
# [22:50:08]   árbol 25/72 | {'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6753
# [22:50:18]   árbol 26/72 | {'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6753
# [22:50:30]   árbol 27/72 | {'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6757
# [22:50:41]   árbol 28/72 | {'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6753
# [22:50:54]   árbol 29/72 | {'max_depth': 8, 'min_samples_leaf': 20, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6762
# [22:51:06]   árbol 30/72 | {'max_depth': 8, 'min_samples_leaf': 20, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6753
# [22:51:21]   árbol 31/72 | {'max_depth': 8, 'min_samples_leaf': 20, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6762
# [22:51:34]   árbol 32/72 | {'max_depth': 8, 'min_samples_leaf': 20, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6753
# [22:51:47]   árbol 33/72 | {'max_depth': 8, 'min_samples_leaf': 100, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6749
# [22:51:59]   árbol 34/72 | {'max_depth': 8, 'min_samples_leaf': 100, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6755
# [22:52:13]   árbol 35/72 | {'max_depth': 8, 'min_samples_leaf': 100, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6749
# [22:52:26]   árbol 36/72 | {'max_depth': 8, 'min_samples_leaf': 100, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6755
# [22:52:37]   árbol 37/72 | {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6725
# [22:52:47]   árbol 38/72 | {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6746
# [22:53:02]   árbol 39/72 | {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6739
# [22:53:18]   árbol 40/72 | {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6746
# [22:53:30]   árbol 41/72 | {'max_depth': 10, 'min_samples_leaf': 20, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6741
# [22:53:41]   árbol 42/72 | {'max_depth': 10, 'min_samples_leaf': 20, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6746
# [22:53:53]   árbol 43/72 | {'max_depth': 10, 'min_samples_leaf': 20, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6739
# [22:54:04]   árbol 44/72 | {'max_depth': 10, 'min_samples_leaf': 20, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6746
# [22:54:16]   árbol 45/72 | {'max_depth': 10, 'min_samples_leaf': 100, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6723
# [22:54:27]   árbol 46/72 | {'max_depth': 10, 'min_samples_leaf': 100, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6748
# [22:54:39]   árbol 47/72 | {'max_depth': 10, 'min_samples_leaf': 100, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6723
# [22:54:49]   árbol 48/72 | {'max_depth': 10, 'min_samples_leaf': 100, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6748
# [22:55:08]   árbol 49/72 | {'max_depth': 14, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6779
# [22:55:19]   árbol 50/72 | {'max_depth': 14, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6846
# [22:55:37]   árbol 51/72 | {'max_depth': 14, 'min_samples_leaf': 1, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6796
# [22:55:49]   árbol 52/72 | {'max_depth': 14, 'min_samples_leaf': 1, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6846
# [22:56:06]   árbol 53/72 | {'max_depth': 14, 'min_samples_leaf': 20, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6804
# [22:56:18]   árbol 54/72 | {'max_depth': 14, 'min_samples_leaf': 20, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6846
# [22:56:35]   árbol 55/72 | {'max_depth': 14, 'min_samples_leaf': 20, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6802
# [22:56:46]   árbol 56/72 | {'max_depth': 14, 'min_samples_leaf': 20, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6846
# [22:57:03]   árbol 57/72 | {'max_depth': 14, 'min_samples_leaf': 100, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6818
# [22:57:15]   árbol 58/72 | {'max_depth': 14, 'min_samples_leaf': 100, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6850
# [22:57:29]   árbol 59/72 | {'max_depth': 14, 'min_samples_leaf': 100, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6818
# [22:57:44]   árbol 60/72 | {'max_depth': 14, 'min_samples_leaf': 100, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6850
# [22:58:20]   árbol 61/72 | {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6656
# [22:58:32]   árbol 62/72 | {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6849
# [22:58:57]   árbol 63/72 | {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6692
# [22:59:08]   árbol 64/72 | {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6849
# [22:59:35]   árbol 65/72 | {'max_depth': 20, 'min_samples_leaf': 20, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6730
# [22:59:47]   árbol 66/72 | {'max_depth': 20, 'min_samples_leaf': 20, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6849
# [23:00:11]   árbol 67/72 | {'max_depth': 20, 'min_samples_leaf': 20, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6731
# [23:00:22]   árbol 68/72 | {'max_depth': 20, 'min_samples_leaf': 20, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6849
# [23:00:44]   árbol 69/72 | {'max_depth': 20, 'min_samples_leaf': 100, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6785
# [23:00:56]   árbol 70/72 | {'max_depth': 20, 'min_samples_leaf': 100, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6849
# [23:01:17]   árbol 71/72 | {'max_depth': 20, 'min_samples_leaf': 100, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6785
# [23:01:28]   árbol 72/72 | {'max_depth': 20, 'min_samples_leaf': 100, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6849
# [23:01:28] FASE 1 lista. Mejor: {'max_depth': 14, 'min_samples_leaf': 100, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6850
#
# Mejores hiperparámetros (CV temporal):
#   max_depth: 14
#   min_samples_leaf: 100
#   min_samples_split: 50
#   min_impurity_decrease: 0.0001
# AUC CV temporal (promedio de 4 ventanas): 0.6850
#    max_depth  min_samples_leaf  min_samples_split  min_impurity_decrease  \
# 0         14               100                 50                 0.0001
# 1         14               100                  2                 0.0001
# 2         20               100                 50                 0.0001
# 3         20               100                  2                 0.0001
# 4         20                 1                  2                 0.0001
# 5         20                 1                 50                 0.0001
# 6         20                20                  2                 0.0001
# 7         20                20                 50                 0.0001
# 8         14                 1                  2                 0.0001
# 9         14                 1                 50                 0.0001
#
#      auc_cv
# 0  0.684960
# 1  0.684960
# 2  0.684943
# 3  0.684943
# 4  0.684908
# 5  0.684908
# 6  0.684908
# 7  0.684908
# 8  0.684599
# 9  0.684599

# %%
# Visualización: fijando el resto de hiperparámetros en su mejor valor, AUC CV vs profundidad por hoja.
fijos = {k: mejor_params[k] for k in ["min_samples_split", "min_impurity_decrease"]}
sub = res_df[(res_df["min_samples_split"] == fijos["min_samples_split"]) &
             (res_df["min_impurity_decrease"] == fijos["min_impurity_decrease"])]

plt.figure(figsize=(7, 4.5))
for leaf, color in zip(sorted(param_grid["min_samples_leaf"]), [C_AZUL, C_AQUA, C_AMARILLO]):
    s = sub[sub["min_samples_leaf"] == leaf].sort_values("max_depth")
    plt.plot(s["max_depth"], s["auc_cv"], marker="o", color=color, label=f"min_samples_leaf={leaf}")
plt.xlabel("max_depth")
plt.ylabel("ROC-AUC (CV temporal, promedio de ventanas)")
plt.title("Árbol: AUC de CV temporal según profundidad y min_samples_leaf")
plt.legend(frameon=False,
           title=f"split={fijos['min_samples_split']}, α={fijos['min_impurity_decrease']}, gini")
plt.show()

# %% [markdown]
# **Para interpretar el gráfico:** ahora cada punto es el **promedio de varias ventanas temporales**, no un único holdout, así que la curva debería salir bastante más estable que el zigzag que teníamos antes (ese zigzag era, justamente, el ruido de mirar un solo corte). Lo que esperamos leer con nitidez es el patrón que enseñó la clase: `max_depth` chico hace *underfitting* y `max_depth` grande sin freno (`min_samples_leaf=1`, α=0) hace *overfitting*, con las curvas de `min_samples_leaf` alto sosteniéndose mejor en profundidades grandes.
#
# Elegimos la combinación que **maximiza el AUC de la CV temporal**. Un criterio extra, consistente con la clase: si dos combinaciones quedan dentro del ruido entre folds (mirá la dispersión de `auc_folds`), preferimos la **más rígida** (menor profundidad / mayor `min_samples_leaf` / mayor α) — la clase insistió en que, ante empate, menos flexibilidad es la apuesta segura contra el overfitting, y además reduce el riesgo de haber agarrado un pico de suerte.

# %% [markdown]
# ### Decisión de datos: ¿toda la historia o solo lo reciente? (experimento de "datos rancios")
#
# `train` arranca en **2013**. La Clase 1 tiene el argumento exacto: *"datos de 1980 de churn de un banco no sirven para predecir hoy, porque los patrones no representan lo que pasa hoy"*. Y en la Clase 2 el profe insistió: los gustos cambian y los meses recientes "pesan más". Hay una tensión real contra otra idea de la Clase 1 (más datos → mejor, curva de aprendizaje), así que es una **pregunta empírica** — y la respondemos con la **misma CV temporal**, sin tocar `test_interno`.
#
# Para cada ventana candidata, en cada fold expansivo filtramos el entrenamiento a los últimos *k* meses (relativo al fin de ese fold) antes de ajustar, y comparamos el AUC promedio contra usar toda la historia. La ventana ganadora define la receta de datos del modelo final.

# %%
# Con los hiperparámetros ya elegidos, ¿conviene entrenar con toda la historia o solo con lo reciente?
ventanas_candidatas = [12, 24, 36, None]  # None = toda la historia
factory_arbol = lambda feats: build_tree_pipeline(feats, **mejor_params)

log_progreso(f"FASE 2/5 — Experimento de datos rancios: {len(ventanas_candidatas)} ventanas x {N_FOLDS} folds")
resultados_ventana = []
for meses in ventanas_candidatas:
    filtro = (lambda df, m=meses: filtrar_reciente(df, m))
    auc_mean, _ = cv_temporal_auc(df_train, mejor_feats, factory_arbol, n_folds=N_FOLDS, train_filter=filtro)
    etiqueta = "toda la historia" if meses is None else f"últimos {meses} meses"
    resultados_ventana.append({"ventana": etiqueta, "meses": meses, "auc_cv": auc_mean})
    log_progreso(f"  ventana {etiqueta:<18} | AUC CV {auc_mean:.4f}")

vent_df = pd.DataFrame(resultados_ventana).sort_values("auc_cv", ascending=False).reset_index(drop=True)
_mejor = vent_df.loc[0, "meses"]
VENTANA_TRAIN_MESES = None if (_mejor is None or (isinstance(_mejor, float) and pd.isna(_mejor))) else int(_mejor)
log_progreso(f"FASE 2 lista. Ventana elegida: {vent_df.loc[0, 'ventana']} (AUC CV {vent_df.loc[0, 'auc_cv']:.4f})")
print("VENTANA_TRAIN_MESES =", VENTANA_TRAIN_MESES)
# Out:
# [23:01:28] FASE 2/5 — Experimento de datos rancios: 4 ventanas x 4 folds
# [23:01:33]   ventana últimos 12 meses   | AUC CV 0.6839
# [23:01:43]   ventana últimos 24 meses   | AUC CV 0.6885
# [23:01:53]   ventana últimos 36 meses   | AUC CV 0.6877
# [23:02:08]   ventana toda la historia   | AUC CV 0.6850
# [23:02:08] FASE 2 lista. Ventana elegida: últimos 24 meses (AUC CV 0.6885)
# VENTANA_TRAIN_MESES = 24

# %% [markdown]
# ### Importancia de atributos del árbol elegido
#
# La clase mostró cómo un árbol rankea variables: cada corte genera una "ganancia" (cuánto baja la impureza), y sumando las ganancias de todos los cortes que usan una variable se obtiene su importancia total. scikit-learn ya la calcula (`.feature_importances_`); la normalizamos a escala 0-100 (100 = la variable con más ganancia acumulada), igual que en clase. El árbol se ajusta con los hiperparámetros elegidos y sobre la ventana de datos elegida (`VENTANA_TRAIN_MESES`).

# %%
df_train_final = filtrar_reciente(df_train, VENTANA_TRAIN_MESES)
best_tree_pipeline = build_tree_pipeline(mejor_feats, **mejor_params)
best_tree_pipeline.fit(*build_xy(df_train_final, mejor_feats))

nombres_onehot = best_tree_pipeline.named_steps["preprocessor"].get_feature_names_out()
importancias = best_tree_pipeline.named_steps["tree"].feature_importances_

imp_df = pd.DataFrame({"feature": nombres_onehot, "importancia": importancias})
imp_df = imp_df[imp_df["importancia"] > 0].sort_values("importancia", ascending=False)
imp_df["importancia_norm"] = 100 * imp_df["importancia"] / imp_df["importancia"].max()

top_n = 15
top_imp = imp_df.head(top_n).iloc[::-1].copy()
top_imp["feature"] = top_imp["feature"].str.replace("onehot__", "", regex=False)

_ventana_txt = "toda la historia" if VENTANA_TRAIN_MESES is None else f"últimos {VENTANA_TRAIN_MESES} meses"
plt.figure(figsize=(7, 5))
plt.barh(top_imp["feature"], top_imp["importancia_norm"], color=C_AZUL)
plt.xlabel("Importancia (0-100, relativa a la variable más importante)")
plt.title(f"Top {top_n} variables | depth={mejor_params['max_depth']}, "
          f"leaf={mejor_params['min_samples_leaf']} | {_ventana_txt}")
plt.tight_layout()
plt.show()

print(f"Columnas post one-hot usadas por el árbol: {len(imp_df)} de {len(nombres_onehot)}")
# Out:
# Columnas post one-hot usadas por el árbol: 38 de 124

# %% [markdown]
# ### Comparación final honesta: árbol vs. KNN, evaluados una única vez en `test_interno`
#
# Ahora sí, el momento del test: lo tocamos **una sola vez**, con los dos modelos ya elegidos (no volvemos a tunear nada mirando este número). Es la única manera de responder "¿cuál de los dos es mejor?" sin el sesgo optimista de haber espiado el resultado muchas veces.
#
# Para que sea una carrera justa, el campeón de KNN (features del conjunto C) se **reconstruye dentro de esta misma partición** y su K se elige con la **misma CV temporal** que usamos para el árbol (antes era un holdout aleatorio; ahora los dos modelos se seleccionan con idéntico régimen de validación). La muestra para entrenarlo sale solo de `train`, nunca de `test_interno`.
#
# Por costo (KNN calcula distancia contra toda su muestra por predicción) evaluamos a ambos sobre una **submuestra estratificada de `test_interno`** de 30.000 filas; el árbol, barato de predecir, lo evaluamos además sobre el `test_interno` completo como chequeo de robustez.

# %% [markdown]
# Para reconstruir el campeón necesitamos el mismo pipeline de KNN de la Clase 1: one-hot encoding (la distancia euclídea no tiene sentido entre categorías) + escalado por desvío estándar sin centrar (`with_mean=False`, porque el output de `OneHotEncoder` es *sparse* y centrar lo volvería denso). El detalle completo de por qué escalar ayuda está en `01_tp_spotify_clase1_knn.ipynb`.

# %%
def build_knn_pipeline(k, features):
    preprocessor = ColumnTransformer(
        transformers=[
            ("onehot", OneHotEncoder(handle_unknown="ignore"), features),
        ],
        remainder="drop",
    )
    return Pipeline(
        steps=[
            ("preprocessor", preprocessor),
            ("scaler", StandardScaler(with_mean=False)),
            ("knn", KNeighborsClassifier(n_neighbors=k)),
        ]
    )

# %%
# --- Elegir K del campeón de KNN con la MISMA CV temporal (subsample para que sea factible) ---
KNN_SAMPLE_SIZE = 100_000   # tamaño de la muestra de entrenamiento del campeón final
KNN_CV_TRAIN = 60_000       # tope de train por fold en la CV (KNN es caro)
KNN_CV_VAL = 20_000         # tope de val por fold en la CV

candidatos_k = [101, 701, 1501]
log_progreso(f"FASE 3/5 — Selección de K para KNN: {len(candidatos_k)} candidatos x 3 folds (lento: KNN predice)")
mejor_k_final, mejor_auc_knn_val = None, -1.0
for k in candidatos_k:
    factory_knn = lambda feats, kk=k: build_knn_pipeline(kk, feats)
    auc_mean, _ = cv_temporal_auc(df_train, mejor_feats, factory_knn, n_folds=3,
                                  subsample=KNN_CV_TRAIN, val_subsample=KNN_CV_VAL)
    log_progreso(f"  K={k:>5} | ROC-AUC CV temporal = {auc_mean:.4f}")
    if auc_mean > mejor_auc_knn_val:
        mejor_k_final, mejor_auc_knn_val = k, auc_mean

log_progreso(f"FASE 3 lista. K elegido: {mejor_k_final}")

# Campeón final de KNN: entrenar en una muestra de df_train (sin fuga de test_interno)
knn_sample, _ = train_test_split(
    df_train, train_size=KNN_SAMPLE_SIZE, stratify=df_train["target"], random_state=RANDOM_STATE,
)
X_knn_train, y_knn_train = build_xy(knn_sample, mejor_feats)
knn_champion = build_knn_pipeline(mejor_k_final, mejor_feats)
knn_champion.fit(X_knn_train, y_knn_train);
# Out:
# [23:02:10] FASE 3/5 — Selección de K para KNN: 3 candidatos x 3 folds (lento: KNN predice)
# [23:03:21]   K=  101 | ROC-AUC CV temporal = 0.6470
# [23:05:01]   K=  701 | ROC-AUC CV temporal = 0.6614
# [23:06:32]   K= 1501 | ROC-AUC CV temporal = 0.6559
# [23:06:32] FASE 3 lista. K elegido: 701

# %%
# --- Comparación final: una única mirada a test_interno ---
log_progreso("FASE 4/5 — Comparación final en test_interno (KNN predice 30k contra su muestra de 100k: tarda)")
test_sample, _ = train_test_split(
    df_test_interno, train_size=30_000, stratify=df_test_interno["target"], random_state=RANDOM_STATE,
)
X_test_cmp, y_test_cmp = build_xy(test_sample, mejor_feats)

auc_knn_test = roc_auc_score(y_test_cmp, knn_champion.predict_proba(X_test_cmp)[:, 1])
auc_tree_test = roc_auc_score(y_test_cmp, best_tree_pipeline.predict_proba(X_test_cmp)[:, 1])
auc_tree_test_full = roc_auc_score(y_te, best_tree_pipeline.predict_proba(X_te)[:, 1])

_ventana_txt = "toda la historia" if VENTANA_TRAIN_MESES is None else f"últimos {VENTANA_TRAIN_MESES} meses"
print("=== ROC-AUC en test_interno (tocado una única vez) ===")
print(f"KNN   (K={mejor_k_final}, muestra {KNN_SAMPLE_SIZE//1000}k de train)                 : {auc_knn_test:.4f}")
print(f"Árbol ({mejor_params}, {_ventana_txt}): {auc_tree_test:.4f}")
print(f"\nÁrbol sobre TODO test_interno ({len(df_test_interno)} filas, chequeo de robustez): {auc_tree_test_full:.4f}")

ganador = "Árbol de decisión" if auc_tree_test > auc_knn_test else "KNN"
log_progreso(f"FASE 4 lista. Árbol {auc_tree_test:.4f} vs KNN {auc_knn_test:.4f} -> gana {ganador}")
print(f"\nGanador en test_interno: {ganador}")
# Out:
# [23:06:33] FASE 4/5 — Comparación final en test_interno (KNN predice 30k contra su muestra de 100k: tarda)
# === ROC-AUC en test_interno (tocado una única vez) ===
# KNN   (K=701, muestra 100k de train)                 : 0.6330
# Árbol ({'max_depth': 14, 'min_samples_leaf': 100, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001}, últimos 24 meses): 0.6589
#
# Árbol sobre TODO test_interno (136702 filas, chequeo de robustez): 0.6585
# [23:07:41] FASE 4 lista. Árbol 0.6589 vs KNN 0.6330 -> gana Árbol de decisión
#
# Ganador en test_interno: Árbol de decisión

# %% [markdown]
# ### Modelo final: reentrenar con el 100% de los datos y submission
#
# Con la receta ya elegida y validada (features, `max_depth`, `min_samples_leaf`) y ya sabiendo honestamente qué tan bien predice en `test_interno`, seguimos la misma práctica que en la Clase 1: el modelo que va a Kaggle se reentrena con el **100% de las filas de train** — ya no hace falta reservar nada, la validación cumplió su rol — porque más datos solo puede ayudar, y un árbol, a diferencia de KNN, entrena rápido incluso con el dataset completo.

# %%
# Modelo final: misma receta (features + hiperparámetros + ventana de datos), reentrenada con
# el 100% de train_raw filtrado por la ventana elegida (incluye los datos más recientes, hasta 2024-08-31).
log_progreso("Modelo final + submission (rápido; después arranca la FASE 5, la última)")
train_raw_final = filtrar_reciente(train_raw, VENTANA_TRAIN_MESES)
final_tree_pipeline = build_tree_pipeline(mejor_feats, **mejor_params)
final_tree_pipeline.fit(*build_xy(train_raw_final, mejor_feats))

# Cargar el test de la competencia y aplicar las mismas derivaciones que en train
# (mismo TOP_ARTISTAS aprendido solo de train, para no filtrar información del test)
test_raw = pd.read_csv(
    f"{DATA_DIR}/test_data.txt", sep="\t",
    usecols=[c for c in USECOLS if c != "ms_played"], dtype=DTYPES,
)
test_raw["content_type"] = np.select(
    [test_raw["spotify_track_uri"].notna(),
     test_raw["spotify_episode_uri"].notna(),
     test_raw["audiobook_uri"].notna()],
    ["track", "episode", "audiobook"],
    default="desconocido",
)
ts_test = pd.to_datetime(test_raw["ts"], utc=True, format="ISO8601")
test_raw["hora"] = ts_test.dt.hour
test_raw["dia_semana"] = ts_test.dt.dayofweek.map(dict(enumerate(DIAS)))
test_raw["artista_top"] = test_raw[col_artista].where(
    test_raw[col_artista].isin(TOP_ARTISTAS), "otros"
)

X_test_kaggle = test_raw[mejor_feats].fillna("missing").astype(str)
test_pred_proba_tree = final_tree_pipeline.predict_proba(X_test_kaggle)[:, 1]

submission_tree = pd.DataFrame({
    "obs_id": test_raw["obs_id"],
    "target": test_pred_proba_tree,
})
submission_tree.to_csv("../submissions/02_submission_clase2_arbol.csv", index=False)
print("Guardado 02_submission_clase2_arbol.csv —", len(submission_tree), "filas")
submission_tree.head()
# Out:
# [23:07:41] Modelo final + submission (rápido; después arranca la FASE 5, la última)
# Guardado 02_submission_clase2_arbol.csv — 51570 filas
#    obs_id    target
# 0  911345  0.193069
# 1  911346  0.274094
# 2  911347  0.077741
# 3  911348  0.077741
# 4  911349  0.077741

# %% [markdown]
# ### Notas honestas para el informe — Clase 2 (con los números de la corrida 2026-07-03)
#
# - **Qué se agregó respecto de la Clase 1:** esquema cronológico train/test_interno (85/15) con **CV temporal de ventana expansiva** dentro de train para todas las decisiones; árbol de decisión con pipeline sin escalado (los árboles no lo necesitan); selección de hiperparámetros y comparación honesta contra KNN en `test_interno` tocado una sola vez.
# - **Mejoras de esta versión (todas dentro del temario de Clases 1–2) y sus números:**
#   1. **Validación temporal multi-ventana (ventana expansiva)** en lugar de un holdout cronológico único: señal menos ruidosa, `argmax` más confiable, menos "overfitting the validation set". El validation fijo se eliminó (train pasa de 70% a 85%).
#   2. **Grilla CONJUNTA** (72 combos × 4 ventanas): ganó `max_depth=14, min_samples_leaf=100, min_samples_split=50, α=1e-4` con **AUC CV 0.6850**. El α=1e-4 aparece en casi todas las configs ganadoras — la poda de la clase ("lo más común en la práctica") funciona: a `max_depth=20` sin α el AUC cae a 0.665-0.673, con α se sostiene en 0.6849. `criterion` quedó fijo en gini por cómputo (casi equivalente según la clase).
#   3. **Experimento de datos rancios:** ganó **últimos 24 meses (AUC CV 0.6885)** sobre 36 meses (0.6877), toda la historia (0.6850) y 12 meses (0.6839). Entrenar con menos datos pero más frescos mejora — los datos viejos no solo no suman: restan. Confirma la intuición del profesor ("los meses recientes pesan más") con número propio.
# - **Comparación honesta en `test_interno` (única mirada):** árbol (receta de arriba + ventana 24m) **0.6589** en la submuestra de 30k y **0.6585** en el `test_interno` completo, vs. KNN (K=701, elegido con la misma CV) **0.6330**. La versión anterior del árbol daba 0.6420/0.6394 → la receta nueva mejora ~1.7 puntos de AUC en el mismo test.
# - **Experimento `user_id` — resultado abierto (ver veredicto al final):** bajo CV temporal multi-ventana la feature **suma** (+0.0146: 0.6996 vs. 0.6850, mejor config `depth=8, leaf=1, α=1e-4`), contradiciendo al holdout único del notebook anterior (donde restaba 2.1 puntos). La causa de la diferencia está analizada en la celda de veredicto; la decisión de adoptarla o no queda pendiente de arbitraje (segunda mirada a test_interno y/o leaderboard público).
# - **Punto de vista a explicitar:** el árbol minimiza impureza (Gini) internamente, pero la *selección* de hiperparámetros se hace por AUC en la CV temporal. Son dos cosas distintas a propósito (la clase: "evaluás con la métrica que te importa").
# - **Cuidado con features de calendario absolutas:** `hora` y `dia_semana` son cíclicas y estables. `mes`/`año` serían time-absolute y no generalizan a la ventana futura del test.
# - **Limitaciones / próximos pasos:** no se re-corrió la comparación de conjuntos de features (A/B/C) específicamente para el árbol. XGBoost (adelantado por el profe como "el modelo del TP") queda para su clase: los árboles de acá son su base conceptual.
# - **Submissions:** `02_submission_clase2_arbol.csv` regenerado por esta corrida — receta: **sin `user_id`**, ventana 24 meses, `depth=14, leaf=100, split=50, α=1e-4`, reentrenada con el 100% del train filtrado. Expectativa según test_interno: ~0.66. La versión anterior del archivo queda en git. Falta subir a Kaggle y anotar el score público.

# %% [markdown]
# ## Mejora dentro del temario (Clases 1–2): revisar la exclusión de `user_id`
#
# Con la Clase 2 cerrada, repasamos qué herramienta ya vista quedó sin explotar. La mejora más fuerte disponible no es una técnica nueva: es una **decisión de la Clase 1 que la Clase 2 da argumentos para revisar**. En la Clase 1 excluimos `user_id` por ser "identificador, no una característica generalizable". Revisado contra los datos crudos y contra lo que dice la clase, ese argumento no se sostiene acá:
#
# - **El problema de los identificadores es la cardinalidad, no el nombre.** La clase lo mostró con el ejemplo del DNI: una variable con tantas categorías como filas permite una rama por observación → overfitting perfecto e inservible. `user_id` es exactamente lo contrario: **10 valores para 911.344 filas** (~90.000 observaciones por usuario; verificado sobre los archivos). La tasa de abandono de cada usuario se estima con decenas de miles de casos — es una categórica de cardinalidad bajísima, con menos categorías que `artista_top`.
# - **Generaliza exactamente a donde se va a usar el modelo.** El esquema *leave-one-group-out* de la clase aplica cuando se quiere predecir en un grupo nuevo (la "provincia donde la empresa todavía no está"). No es nuestro caso: **los 10 usuarios del test de Kaggle son los mismos 10 del train** (verificado). El modelo va a predecir para las mismas personas, más adelante en el tiempo — y nuestro split cronológico replica exactamente ese escenario, que es el criterio de la clase: que validación replique el uso real.
# - **El árbol es el modelo ideal para esta variable.** Cada hoja predice la proporción de clases de su región: un corte por usuario le da a cada uno su propia tasa base de abandono, y los cortes anidados captan interacciones usuario × hora, usuario × artista — la clase destacó que los árboles "captan interacciones de manera automática".
#
# Protocolo de siempre, el que la clase usó para "¿escalar sí o no?": **una decisión nueva, un número que la valida**. Se re-corre la misma grilla conjunta **con la misma CV temporal**, con el único cambio de agregar `user_id`, y se compara contra el mejor árbol sin ella. `test_interno` no se toca en este experimento.

# %%
# Diagnóstico previo, solo con train (validation/test_interno no se miran para esto):
# si la tasa de abandono varía mucho entre usuarios, la variable trae señal real.
diag_usuarios = (
    df_train.groupby("user_id")["target"]
    .agg(filas="size", tasa_abandono="mean")
    .sort_values("tasa_abandono", ascending=False)
)
print(f"Usuarios distintos en train: {len(diag_usuarios)} | tasa global de train: {df_train['target'].mean():.4f}")
diag_usuarios.round(4)
# Out:
# Usuarios distintos en train: 10 | tasa global de train: 0.2865
#                                                      filas  tasa_abandono
# user_id
# 11ce99f6dfdbdeb01412471d46993e4a707c2b3d5e6eaed...  115030         0.5395
# eb975aec35e98925ded94e6e978a3fad6d1c06753c2184c...   57875         0.4615
# 54971d5ef686772751635cfbca7cef7abc2db839df50151...  115128         0.3765
# c905c2404d23b7d8045df9cf8fe53501df8fb1f0aa175b4...   64690         0.2668
# 607e9350fb5a26619dbe8c98c365fefbb1ca118fb6f43ef...     169         0.2604
# a5260fbfb7b2be30fc12bff12c239bbe222a16172e6fb99...   72721         0.2591
# b351cbfbc30090334ba87d0133bf70f114f3d6dacd9ac4d...   44586         0.2453
# 6c4d27bcd20d8761de4668d221110c98b4030dca1787a20...   45282         0.1990
# 18f72490eac4fa92741faf45964a9135301dbd0b7409454...   74095         0.1580
# 3175a05fd828cb5c38584fc33fc95e013cd953e1adf8f69...  185066         0.1191

# %%
# Misma grilla conjunta y misma CV temporal; la única decisión nueva es sumar user_id.
FEATURES_V2 = TODAS_LAS_FEATURES + ["user_id"]

log_progreso(f"FASE 5/5 — Experimento user_id: {len(combos)} combinaciones x {N_FOLDS} folds")
resultados_v2 = []
for i, params in enumerate(combos, 1):
    factory = lambda feats, p=params: build_tree_pipeline(feats, **p)
    auc_mean, _ = cv_temporal_auc(df_train, FEATURES_V2, factory, n_folds=N_FOLDS)
    resultados_v2.append({**params, "auc_cv": auc_mean})
    log_progreso(f"  user_id {i}/{len(combos)} | {params} | AUC CV {auc_mean:.4f}")

res_v2 = pd.DataFrame(resultados_v2).sort_values("auc_cv", ascending=False).reset_index(drop=True)
mejor_auc_v2 = float(res_v2.loc[0, "auc_cv"])

log_progreso(f"FASE 5 lista. CON user_id {mejor_auc_v2:.4f} vs SIN {mejor_auc_arbol:.4f} "
             f"({mejor_auc_v2 - mejor_auc_arbol:+.4f}). Corrida completa.")

print(f"Mejor AUC CV temporal SIN user_id: {mejor_auc_arbol:.4f}")
print(f"Mejor AUC CV temporal CON user_id: {mejor_auc_v2:.4f}")
print(f"Diferencia por sumar user_id:      {mejor_auc_v2 - mejor_auc_arbol:+.4f}")
print("Config ganadora con user_id:", {k: res_v2.loc[0, k] for k in param_grid})
# Out:
# [23:07:43] FASE 5/5 — Experimento user_id: 72 combinaciones x 4 folds
# [23:07:53]   user_id 1/72 | {'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6901
# [23:08:02]   user_id 2/72 | {'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6902
# [23:08:11]   user_id 3/72 | {'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6901
# [23:08:19]   user_id 4/72 | {'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6902
# [23:08:28]   user_id 5/72 | {'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6901
# [23:08:38]   user_id 6/72 | {'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6902
# [23:08:47]   user_id 7/72 | {'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6901
# [23:08:56]   user_id 8/72 | {'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6902
# [23:09:05]   user_id 9/72 | {'max_depth': 4, 'min_samples_leaf': 100, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6901
# [23:09:14]   user_id 10/72 | {'max_depth': 4, 'min_samples_leaf': 100, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6902
# [23:09:23]   user_id 11/72 | {'max_depth': 4, 'min_samples_leaf': 100, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6901
# [23:09:31]   user_id 12/72 | {'max_depth': 4, 'min_samples_leaf': 100, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6902
# [23:09:43]   user_id 13/72 | {'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6949
# [23:09:53]   user_id 14/72 | {'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6957
# [23:10:03]   user_id 15/72 | {'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6949
# [23:10:12]   user_id 16/72 | {'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6957
# [23:10:22]   user_id 17/72 | {'max_depth': 6, 'min_samples_leaf': 20, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6949
# [23:10:32]   user_id 18/72 | {'max_depth': 6, 'min_samples_leaf': 20, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6957
# [23:10:43]   user_id 19/72 | {'max_depth': 6, 'min_samples_leaf': 20, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6949
# [23:10:53]   user_id 20/72 | {'max_depth': 6, 'min_samples_leaf': 20, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6957
# [23:11:04]   user_id 21/72 | {'max_depth': 6, 'min_samples_leaf': 100, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6953
# [23:11:14]   user_id 22/72 | {'max_depth': 6, 'min_samples_leaf': 100, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6957
# [23:11:23]   user_id 23/72 | {'max_depth': 6, 'min_samples_leaf': 100, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6953
# [23:11:33]   user_id 24/72 | {'max_depth': 6, 'min_samples_leaf': 100, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6957
# [23:11:44]   user_id 25/72 | {'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6975
# [23:11:56]   user_id 26/72 | {'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6996
# [23:12:08]   user_id 27/72 | {'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6983
# [23:12:19]   user_id 28/72 | {'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6996
# [23:12:31]   user_id 29/72 | {'max_depth': 8, 'min_samples_leaf': 20, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6980
# [23:12:42]   user_id 30/72 | {'max_depth': 8, 'min_samples_leaf': 20, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6996
# [23:12:55]   user_id 31/72 | {'max_depth': 8, 'min_samples_leaf': 20, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6980
# [23:13:06]   user_id 32/72 | {'max_depth': 8, 'min_samples_leaf': 20, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6996
# [23:13:17]   user_id 33/72 | {'max_depth': 8, 'min_samples_leaf': 100, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6981
# [23:13:28]   user_id 34/72 | {'max_depth': 8, 'min_samples_leaf': 100, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6993
# [23:13:40]   user_id 35/72 | {'max_depth': 8, 'min_samples_leaf': 100, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6981
# [23:13:51]   user_id 36/72 | {'max_depth': 8, 'min_samples_leaf': 100, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6993
# [23:14:07]   user_id 37/72 | {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6910
# [23:14:18]   user_id 38/72 | {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6994
# [23:14:32]   user_id 39/72 | {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6926
# [23:14:44]   user_id 40/72 | {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6994
# [23:14:58]   user_id 41/72 | {'max_depth': 10, 'min_samples_leaf': 20, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6925
# [23:15:11]   user_id 42/72 | {'max_depth': 10, 'min_samples_leaf': 20, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6994
# [23:15:27]   user_id 43/72 | {'max_depth': 10, 'min_samples_leaf': 20, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6925
# [23:15:42]   user_id 44/72 | {'max_depth': 10, 'min_samples_leaf': 20, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6994
# [23:15:56]   user_id 45/72 | {'max_depth': 10, 'min_samples_leaf': 100, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6959
# [23:16:08]   user_id 46/72 | {'max_depth': 10, 'min_samples_leaf': 100, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6985
# [23:16:23]   user_id 47/72 | {'max_depth': 10, 'min_samples_leaf': 100, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6959
# [23:16:35]   user_id 48/72 | {'max_depth': 10, 'min_samples_leaf': 100, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6985
# [23:17:01]   user_id 49/72 | {'max_depth': 14, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6839
# [23:17:14]   user_id 50/72 | {'max_depth': 14, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6987
# [23:17:40]   user_id 51/72 | {'max_depth': 14, 'min_samples_leaf': 1, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6872
# [23:17:53]   user_id 52/72 | {'max_depth': 14, 'min_samples_leaf': 1, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6987
# [23:18:18]   user_id 53/72 | {'max_depth': 14, 'min_samples_leaf': 20, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6913
# [23:18:31]   user_id 54/72 | {'max_depth': 14, 'min_samples_leaf': 20, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6987
# [23:19:02]   user_id 55/72 | {'max_depth': 14, 'min_samples_leaf': 20, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6913
# [23:19:13]   user_id 56/72 | {'max_depth': 14, 'min_samples_leaf': 20, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6987
# [23:19:32]   user_id 57/72 | {'max_depth': 14, 'min_samples_leaf': 100, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6965
# [23:19:45]   user_id 58/72 | {'max_depth': 14, 'min_samples_leaf': 100, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6976
# [23:20:04]   user_id 59/72 | {'max_depth': 14, 'min_samples_leaf': 100, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6965
# [23:20:16]   user_id 60/72 | {'max_depth': 14, 'min_samples_leaf': 100, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6976
# [23:20:55]   user_id 61/72 | {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6699
# [23:21:07]   user_id 62/72 | {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6988
# [23:21:39]   user_id 63/72 | {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6778
# [23:21:54]   user_id 64/72 | {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6988
# [23:22:25]   user_id 65/72 | {'max_depth': 20, 'min_samples_leaf': 20, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6852
# [23:22:38]   user_id 66/72 | {'max_depth': 20, 'min_samples_leaf': 20, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6988
# [23:23:18]   user_id 67/72 | {'max_depth': 20, 'min_samples_leaf': 20, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6855
# [23:23:32]   user_id 68/72 | {'max_depth': 20, 'min_samples_leaf': 20, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6988
# [23:24:02]   user_id 69/72 | {'max_depth': 20, 'min_samples_leaf': 100, 'min_samples_split': 2, 'min_impurity_decrease': 0.0} | AUC CV 0.6962
# [23:24:20]   user_id 70/72 | {'max_depth': 20, 'min_samples_leaf': 100, 'min_samples_split': 2, 'min_impurity_decrease': 0.0001} | AUC CV 0.6978
# [23:25:06]   user_id 71/72 | {'max_depth': 20, 'min_samples_leaf': 100, 'min_samples_split': 50, 'min_impurity_decrease': 0.0} | AUC CV 0.6962
# [23:25:21]   user_id 72/72 | {'max_depth': 20, 'min_samples_leaf': 100, 'min_samples_split': 50, 'min_impurity_decrease': 0.0001} | AUC CV 0.6978
# [23:25:21] FASE 5 lista. CON user_id 0.6996 vs SIN 0.6850 (+0.0146). Corrida completa.
# Mejor AUC CV temporal SIN user_id: 0.6850
# Mejor AUC CV temporal CON user_id: 0.6996
# Diferencia por sumar user_id:      +0.0146
# Config ganadora con user_id: {'max_depth': np.int64(8), 'min_samples_leaf': np.int64(1), 'min_samples_split': np.int64(2), 'min_impurity_decrease': np.float64(0.0001)}

# %% [markdown]
# ### Veredicto del experimento `user_id`: SUMA bajo CV temporal (+0.0146) — y contradice al holdout único
#
# **Resultado real de la corrida (2026-07-03):** mejor AUC CV temporal **CON** `user_id` = **0.6996** (config: `max_depth=8, min_samples_leaf=1, min_samples_split=2, α=1e-4`) vs. **SIN** = **0.6850**. La feature **suma +0.0146**.
#
# Esto **contradice** el experimento anterior (notebook `02_tp_spotify_clase2_arboles.ipynb`): con un **holdout cronológico único** (train hasta 2022-01, validation 2022-01→2023-05), `user_id` *restaba* 2.1 puntos (0.6478 vs. 0.6690). Las dos mediciones son honestas; miden cosas distintas:
#
# - El **holdout único** midió *una sola* transferencia, larga y particular: todo el pasado → la época 2022-2023, justo cuando un usuario pesado invirtió su comportamiento (8% → 44% de abandono, 4× de actividad). Ahí la señal por usuario se rompía.
# - La **CV expansiva** promedia varias transferencias **al futuro inmediato** (cada ventana valida en el bloque siguiente). En promedio, la tasa por usuario del pasado reciente sí predice el bloque que viene. Además, todas las configs ganadoras llevan **α=1e-4**: la poda regulariza los cortes por usuario, el modo de falla del experimento anterior.
# - ¿Cuál régimen se parece más al test real de Kaggle (sep–dic 2024, inmediatamente después del fin del train)? El de la CV — validar en el futuro inmediato. Pero el test real es *una* época concreta, que puede tener su propio salto de comportamiento como el de 2022.
#
# **Decisión pendiente (no automática):** cómo arbitrar la contradicción antes de elegir la receta de la submission. Candidatas: (a) una **segunda mirada deliberada y documentada** a `test_interno` con la variante `user_id` (la más informativa: mide la transferencia a la época más reciente disponible); (b) subir ambas recetas a Kaggle y dejar que el leaderboard público decida. La submission generada por esta corrida **no** incluye `user_id`.
#
# **Moraleja para el informe (mejor aún que la original):** la conclusión "user_id no sirve" dependía del esquema de validación. Ningún número de validación es *la verdad* — cada esquema responde una pregunta distinta, y hay que elegir el que replica el uso real del modelo. Eso es exactamente lo que la clase quiso enseñar con "cómo armar un buen validation set es trabajo del data scientist".
